# %% [markdown]
#  **Exploring and Cleaning the DataSet**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/spotify dataset.csv');

# %%
df.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# ...

# %%
#Checking null
pd.isnull(df).sum()
# Out:
# track_id                    0
# track_name                  3
# track_artist                3
# track_popularity            0
# track_album_id              0
# track_album_name            3
# track_album_release_date    0
# playlist_name               0
# playlist_id                 0
# playlist_genre              0
# playlist_subgenre           0
# danceability                1
# energy                      1
# key                         1
# loudness                    1
# mode                        1
# speechiness                 1
# acousticness                1
# instrumentalness            1
# liveness                    1
# valence                     1
# tempo                       1
# duration_ms                 1
# dtype: int64

# %%
#Checking info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32833 non-null  object
#  7   playlist_name             32833 non-null  object
#  8   playlist_id               32833 non-null  object
#  9   playlist_genre            32833 non-null  object
#  10  playlist_subgenre         32833 non-null  object
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
# ...

# %%
#Finding the least 30 popular songs in the datset
a = df.sort_values('track_popularity',ascending=True)[0:30]
a[['track_name','track_popularity']]
# Out:
#                               track_name  track_popularity
# 11645                El Laberinto - Live                 0
# 18994                           Un Sueño                 0
# 19127                    No Es Culpa Mía                 0
# 19160                            Web Cam                 0
# 19168                        Sexo Seguro                 0
# 19178                      Flow Violento                 0
# 19186                Nuestro Amor Es Asi                 0
# 11457                     Natsu No Owari                 0
# 27749                           Stardust                 0
# 27747                   Thanks A Million                 0
# 27744                  Show Me Your Love                 0
# 27742                         Lift Me Up                 0
# 27741             Kinetic (Original Mix)                 0
# 27740                          Boomslang                 0
# 18993                Dejale Caer To Peso                 0
# ...

# %%
#Descriptive statistics
df.describe().transpose()
# Out:
#                     count           mean           std          min  \
# track_popularity  32833.0      42.477081     24.984074     0.000000
# danceability      32833.0       0.654850      0.145085     0.000000
# energy            32833.0       0.698619      0.180910     0.000175
# key               32833.0       5.374471      3.611657     0.000000
# loudness          32833.0      -6.719499      2.988436   -46.448000
# mode              32833.0       0.565711      0.495671     0.000000
# speechiness       32833.0       0.107068      0.101314     0.000000
# acousticness      32833.0       0.175334      0.219633     0.000000
# instrumentalness  32833.0       0.084747      0.224230     0.000000
# liveness          32833.0       0.190176      0.154317     0.000000
# valence           32833.0       0.510561      0.233146     0.000000
# tempo             32833.0     120.881132     26.903624     0.000000
# duration_ms       32833.0  225799.811622  59834.006182  4000.000000
#
# ...

# %%
df.columns.values
# Out:
# array(['track_id', 'track_name', 'track_artist', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre',
#        'playlist_subgenre', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'duration_ms'], dtype=object)

# %%
df.drop_duplicates(subset=['track_id'],keep='first',inplace=True)

# %%
#Drop unused columns
df.drop(['track_id','track_album_id','playlist_subgenre','playlist_subgenre'],axis=1,inplace=True)

# %%
#finding top 10 popular songs in the spotify dataset
a = df
b= a[a['track_popularity']>97].sort_values('track_popularity',ascending=False)[:10]
b[['track_name','track_popularity','track_artist']]
# Out:
#                             track_name  track_popularity    track_artist
# track_album_release_date
# 2019-10-17                Dance Monkey               100     Tones and I
# 2019-10-17                Dance Monkey               100     Tones and I
# 2019-10-10                     ROXANNE                99  Arizona Zervas
# 2019-10-10                     ROXANNE                99  Arizona Zervas
# 2019-10-10                     ROXANNE                99  Arizona Zervas
# 2019-10-10                     ROXANNE                99  Arizona Zervas
# 2019-11-07                        Tusa                98         KAROL G
# 2019-12-06                     The Box                98     Roddy Ricch
# 2019-09-06                     Circles                98     Post Malone
# 2019-09-20                    Memories                98        Maroon 5

# %%
df.rename(columns={'playlist_id':'month'},inplace=True)

# %%
df.head()
# Out:
#                                           track_name      track_artist  \
# 0  I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                    Memories - Dillon Francis Remix          Maroon 5
# 2                    All the Time - Don Diablo Remix      Zara Larsson
# 3                  Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4            Someone You Loved - Future Humans Remix     Lewis Capaldi
#
#    track_popularity                                   track_album_name  \
# 0                66  I Don't Care (with Justin Bieber) [Loud Luxury...
# 1                67                    Memories (Dillon Francis Remix)
# 2                70                    All the Time (Don Diablo Remix)
# 3                60                        Call You Mine - The Remixes
# 4                69            Someone You Loved (Future Humans Remix)
#
#   track_album_release_date playlist_name                   month  \
# ...

# %%
#Make the release date column as the index column
df.set_index('track_album_release_date',inplace=True)
df.index=pd.to_datetime(df.index)
df.head()
# Out:
#                                         track_id  \
# track_album_release_date
# 2019-06-14                6f807x0ima9a1j3VPbc7VN
# 2019-12-13                0r7CVbZTWZgbTCYdfa2P31
# 2019-07-05                1z1Hg7Vb0AhHDiEmnDE79l
# 2019-07-19                75FpbthrwQmzHlBJLuGdC7
# 2019-03-05                1e8PAfcKUYoKkxPhrHqw4x
#
#                                                                  track_name  \
# track_album_release_date
# 2019-06-14                I Don't Care (with Justin Bieber) - Loud Luxur...
# 2019-12-13                                  Memories - Dillon Francis Remix
# 2019-07-05                                  All the Time - Don Diablo Remix
# 2019-07-19                                Call You Mine - Keanu Silva Remix
# 2019-03-05                          Someone You Loved - Future Humans Remix
#
#                               track_artist  track_popularity  \
# track_album_release_date
# 2019-06-14                      Ed Sheeran                66
# ...

# %% [markdown]
# **Data Visualization**

# %%
df.corr()
# Out:
# <ipython-input-13-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                   track_popularity  danceability    energy       key  \
# track_popularity          1.000000      0.099349 -0.075424 -0.007454
# danceability              0.099349      1.000000 -0.177291  0.003557
# energy                   -0.075424     -0.177291  1.000000  0.010597
# key                      -0.007454      0.003557  0.010597  1.000000
# loudness                  0.039344      0.008290  0.685972  0.000574
# mode                     -0.012599     -0.072113  0.010676 -0.171784
# speechiness              -0.021311      0.226596 -0.032977  0.032117
# acousticness              0.043854      0.055928 -0.539973  0.006884
# instrumentalness         -0.058076     -0.055296 -0.173043  0.019567
# ...

# %%
valence_energy =df.plot.scatter(x='valence',y='energy')

#Scatterplot
x = df['valence']
y = df['energy']
plt.scatter(x,y)

#Plot Trendline
reg = np.polyfit(x,y,1)
trendline=np.poly1d(reg)
plt.plot(x,trendline(x),'r--')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: On entry to DLASCL parameter number 4 had an illegal value
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# <ipython-input-17-29cef661db77> in <cell line: 9>()
#       7
#       8 #Plot Trendline
# ----> 9 reg = np.polyfit(x,y,1)
#      10 trendline=np.poly1d(reg)
#      11 plt.plot(x,trendline(x),'r--')
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in polyfit(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     666     scale = NX.sqrt((lhs*lhs).sum(axis=0))
#     667     lhs /= scale
# --> 668     c, resids, rank, s = lstsq(lhs, rhs, rcond)
#     669     c = (c.T/scale).T  # broadcast scale coefficients
# ...

# %% [markdown]
# **Features plotted over time**

# %%
df.head()
# Out:
#                                           track_name      track_artist  \
# 0  I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                    Memories - Dillon Francis Remix          Maroon 5
# 2                    All the Time - Don Diablo Remix      Zara Larsson
# 3                  Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4            Someone You Loved - Future Humans Remix     Lewis Capaldi
#
#    track_popularity                                   track_album_name  \
# 0                66  I Don't Care (with Justin Bieber) [Loud Luxury...
# 1                67                    Memories (Dillon Francis Remix)
# 2                70                    All the Time (Don Diablo Remix)
# 3                60                        Call You Mine - The Remixes
# 4                69            Someone You Loved (Future Humans Remix)
#
#   track_album_release_date playlist_name                   month  \
# ...

# %%
import pandas as pd

# %%
fig, ax = df[['danceability','valence']].plot(x='danceability', y='valence', figsize=(10, 6))
ax.set_xlabel('Danceability')
ax.set_ylabel('Valence')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-94796fddd821> in <cell line: 1>()
# ----> 1 fig, ax = df[['danceability','valence']].plot(x='danceability', y='valence', figsize=(10, 6))
#       2 ax.set_xlabel('Danceability')
#       3 ax.set_ylabel('Valence')
#
# TypeError: cannot unpack non-iterable Axes object

# %%
print(y)
print(x)
# Out:
# 0        0.916
# 1        0.815
# 2        0.931
# 3        0.930
# 4        0.833
#          ...
# 17576    0.387
# 17577    0.574
# 17578    0.812
# 17579    0.481
# 17580      NaN
# Name: energy, Length: 16084, dtype: float64
# 0        0.518
# 1        0.693
# 2        0.613
# 3        0.277
# 4        0.725
#          ...
# 17576    0.467
# 17577    0.272
# 17578    0.512
# 17579    0.376
# 17580      NaN
# Name: valence, Length: 16084, dtype: float64

# %%
print(y.isnull().sum())
print(x.isnull().sum())
# Out:
# 1
# 1

# %%
print(np.isinf(y).sum())
print(np.isinf(x).sum())
# Out:
# 0
# 0

# %%
print(np.isnan(y).sum())
print(np.isnan(x).sum())
# Out:
# 1
# 1

# %%
# Drop rows with missing values
y = y.dropna()
x = x.dropna()

# Replace infinite values with a large finite value
y = y.replace([np.inf, -np.inf], 1e8)
x = x.replace([np.inf, -np.inf], 1e8)

# Replace NaN values with a suitable value (e.g., 0)
y = y.fillna(0)
x = x.fillna(0)

# %%
model = sm.OLS(y,x)
results = model.fit()
print(results.params)
print(results.tvalues)
# Out:
# valence    1.150996
# dtype: float64
# valence    272.903117
# dtype: float64

# %%
print(type(df[['danceability','valence']].set_index('danceability')))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#Finding the name of the artist present in the 20th row of the dataset
df[['track_artist']].iloc[20]
# Out:
# track_artist    Avicii
# Name: 2019-08-23 00:00:00, dtype: object

# %%
for col in df:
    try:
        x = df['valence']
        y = df[col]

        # Calculate trendline
        reg = np.polyfit(x,y,1)
        trendline = np.poly1d(reg)

        # Scatterplot with trendline
        fig, ax = plt.subplots()
        ax.scatter(x, y)
        ax.plot(x,trendline(x),'r--')
        ax.set_xlabel('valence')
        ax.set_ylabel(col)

        # Boxplot
        box = df.boxplot(col,'valence')
        box.set_xlabel('valence')
        box.set_ylabel(col)
    except:
        print(col)
# Out:
# track_name
# track_artist
# track_popularity
# track_album_name
# track_album_release_date
# playlist_name
# month
# playlist_genre
# danceability
# energy
# key
# loudness
# mode
# speechiness
# acousticness
# instrumentalness
# liveness
# valence
# tempo
# duration_ms

# %%
print(x.dtype)
print(y.dtype)
# Out:
# object
# float64

# %%
if x.dtype == 'str':
    print("x is a string")
else:
    print("x is not a string")

if y.dtype == 'str':
    print("y is a string")
else:
    print("y is not a string")
# Out:
# x is not a string
# y is not a string

# %%
# Scatterplot
x = df['month']
y = df['valence']
plt.scatter(x, y)

# Plot trendline
reg = np.polyfit(x,y,1)
trendline = np.poly1d(reg)

plt.plot(x,trendline(x),'r--')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-d787fd0309bf> in <cell line: 7>()
#       5
#       6 # Plot trendline
# ----> 7 reg = np.polyfit(x,y,1)
#       8 trendline = np.poly1d(reg)
#       9
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in polyfit(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     627     """
#     628     order = int(deg) + 1
# --> 629     x = NX.asarray(x) + 0.0
#     630     y = NX.asarray(y) + 0.0
#     631
#
# TypeError: can only concatenate str (not "float") to str

# %%
df['track_album_release_date'] = pd.to_datetime(df['track_album_release_date'])

# %%
#Correlation heatmap using python correlation method between two variables
td = df.drop(['key','mode'],axis =1).corr(method = 'pearson')
plt.figure(figsize=(9,5))
hmap = sns.heatmap(td,annot=True,fmt='.1g',vmin=-1,vmax=1,center=0,cmap='Greens',linewidths=0.1,linecolor='black')
hmap.set_title('Correlation HeatMap')
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-43-4422795d75d0>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   td = df.drop(['key','mode'],axis =1).corr(method = 'pearson')

# %%
#Sample only 4 percent of the whole dataset
sample_df = df.sample(int(0.004*len(df)))
print(len(sample_df))
# Out:
# 131

# %% [markdown]
# Additional data cleaning: numerical values

# %%
df_numerical = df.select_dtypes(include=[np.number])

# %%
df_numerical.describe()
# Out:
#        track_popularity  danceability        energy           key  \
# count      16084.000000  16083.000000  16083.000000  16083.000000
# mean          42.642129      0.636087      0.690086      5.339054
# std           23.593919      0.154707      0.182046      3.626514
# min            0.000000      0.000000      0.000175      0.000000
# 25%           27.000000      0.534000      0.573000      2.000000
# 50%           47.000000      0.651000      0.712000      6.000000
# 75%           61.000000      0.749000      0.832000      9.000000
# max          100.000000      0.979000      1.000000     11.000000
#
#            loudness          mode   speechiness  acousticness  \
# count  16083.000000  16083.000000  16083.000000  16083.000000
# mean      -6.997970      0.595909      0.110942      0.181051
# std        3.126252      0.490731      0.110296      0.224764
# min      -46.448000      0.000000      0.000000      0.000000
# ...

# %%
#Create a Regression plot between loudness and energy.Let's plot in the form of Regression line
plt.figure(figsize=(8,4))
sns.regplot(data=sample_df,y='loudness',x='energy',color='#054907').set(title='Regression Plot - Loudness vs Energy Correlation')
# Out:
# [Text(0.5, 1.0, 'Regression Plot - Loudness vs Energy Correlation')]

# %%
from sklearn import decomposition

# %%
#Create a Regression plot between Popularity and Acousticness in the form of a Regression Line
plt.figure(figsize=(8,4))
sns.regplot(data=sample_df,y='track_popularity',x='acousticness',color='#008000').set(title='Regression Plot - Popularity vs Acousticness Correlation')
# Out:
# [Text(0.5, 1.0, 'Regression Plot - Popularity vs Acousticness Correlation')]

# %%
#creating new column in tracks table
df['dates'] = df.index.get_level_values('track_album_release_date')
df.dates=pd.to_datetime(df.dates)
years=df.dates.dt.year
df.head()
# Out:
#                                         track_id  \
# track_album_release_date
# 2019-06-14                6f807x0ima9a1j3VPbc7VN
# 2019-12-13                0r7CVbZTWZgbTCYdfa2P31
# 2019-07-05                1z1Hg7Vb0AhHDiEmnDE79l
# 2019-07-19                75FpbthrwQmzHlBJLuGdC7
# 2019-03-05                1e8PAfcKUYoKkxPhrHqw4x
#
#                                                                  track_name  \
# track_album_release_date
# 2019-06-14                I Don't Care (with Justin Bieber) - Loud Luxur...
# 2019-12-13                                  Memories - Dillon Francis Remix
# 2019-07-05                                  All the Time - Don Diablo Remix
# 2019-07-19                                Call You Mine - Keanu Silva Remix
# 2019-03-05                          Someone You Loved - Future Humans Remix
#
#                               track_artist  track_popularity  \
# track_album_release_date
# 2019-06-14                      Ed Sheeran                66
# ...

# %%
sns.displot(years,discrete=True,aspect=2,height=4,kind='hist',color='g').set(title='No of songs - per year')

# %%
#Find top five genres by Popularity and plot a barplot for the same.
sns.set_style(style='darkgrid')
plt.figure(figsize=(8,4))
Top = df.sort_values('track_popularity',ascending=False)[:10]
sns.barplot(y='playlist_genre',x='track_popularity',data=Top).set(title='Genres by Popularity-Top 5')
# Out:
# [Text(0.5, 1.0, 'Genres by Popularity-Top 5')]
